# %%
# Import Dependencies
import numpy as np
import tensorflow as tf
from tensorflow import keras

from keras import backend as K

import os
from pathlib import Path

from keras.optimizers import Adam
from keras.models import Model
from keras.utils import load_img

import pprint

from google.colab import drive
drive.mount('/content/drive')

data_name = "Staten Island"

# Path
input_dir = ""
input_ext = ".png"
target_dir = ""
target_ext = ".png"

# Format
img_size = (256, 256)
input_band_count = 3    # only support 3 (RGB) for now

# Training HyperParameters
batch_size = 10
early_stop_patience = 5
epochs = 100
monitor_function = 'val_jaccard_coef_int' # Defined later

# Data Loader
class ImagesSequence(keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths

    def __len__(self):  # no. of batches
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = np.zeros((self.batch_size,) + self.img_size + (input_band_count,), dtype="float32") #concatnation of tuples; (3,) stands for 1-element tuple

        for j, path in enumerate(batch_input_img_paths):
            if input_band_count == 3:
                img = load_img(path, target_size=self.img_size)
                x[j] = img
                x[j] = x[j] /  255 # Normalize
            else:
                raise NotImplementedError
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="uint8")
        for j, path in enumerate(batch_target_img_paths):
            img = load_img(path, target_size=self.img_size, color_mode="grayscale")
            y[j] = np.expand_dims(img, -1)/255  # Grayscale doesn't have last dimension
        return x, y

# Loadind and Spliting Data
# 10% for testing
# train:val = 4:1
input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(input_ext)
    ]
)
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(target_ext) and not fname.startswith(".")
    ]
)

train_index = slice(None, int(0.72*len(os.listdir(input_dir))))
val_index = slice(int(0.72*len(os.listdir(input_dir))), int(0.9*len(os.listdir(input_dir))))
test_index = slice(int(0.9*len(os.listdir(input_dir))), None)

train_input_img_paths   = input_img_paths[train_index]
train_target_img_paths  = target_img_paths[train_index]
val_input_img_paths     = input_img_paths[val_index]
val_target_img_paths    = target_img_paths[val_index]

train_gen = ImagesSequence(batch_size, img_size, train_input_img_paths, train_target_img_paths)
val_gen = ImagesSequence(batch_size, img_size, val_input_img_paths, val_target_img_paths)

# Monitor Function
# Based on [Winning solution of SpaceNet2](https://github.com/SpaceNetChallenge/BuildingDetectors_Round2/tree/master/1-XD_XD)
# Minimize Jaccard distance := 1-Jaccard coeff, where coeff is intersection / union
def jaccard_coef_int(y_true, y_pred, smooth = 1e-12):
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    intersection = K.sum(y_true * y_pred_pos, axis=[-1, -2, 0])
    sum_ = K.sum(y_true + y_pred_pos, axis=[-1, -2, 0])
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - K.mean(jac)) * smooth
# Out:
# Mounted at /content/drive

# %%
# Model HyperParameters
optimizer_name = "Adam"
learning_rate = 1e-4
weight_decay = 5e-5
loss='binary_crossentropy'
metrics=['accuracy', jaccard_coef_int]
activation = "GELU"
output_activation = "Sigmoid"

# Implementing Model
# !pip3 install keras_unet_collection
from keras_unet_collection import models

model_name = "Unet"
optimizer = keras.optimizers.Adam(learning_rate=learning_rate, weight_decay=weight_decay)
model = models.unet_2d(input_size=(256,256,3), filter_num=[64, 128, 256, 512], n_labels=1, activation = activation, output_activation = output_activation)
model.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=metrics
)
# Out:
# Requirement already satisfied: keras_unet_collection in /usr/local/lib/python3.10/dist-packages (0.1.13)

# %%
model.summary()

# %%
# Training and saving
progress_dir = Path(data_name+" Progress")
train_model_filename = Path(progress_dir, f"model_train.h5")
best_model_filename = Path(progress_dir, f"model_best.h5")
history_csv_filename = Path(progress_dir, f"loss_history.csv")
params_txt_filename = Path(progress_dir, f"params.txt")
model_txt_filename = Path(progress_dir, f"model_summary.txt")

def store_in_dict(*args):
    return {key: globals()[key] for key in args}

training_params = store_in_dict(
    "batch_size", "monitor_function", "early_stop_patience", "epochs"
)
model_params = store_in_dict(
    "optimizer_name", "learning_rate", "weight_decay", "loss", "metrics", "activation", "output_activation"
)

progress_dir.mkdir(parents=True, exist_ok=True)
with open(params_txt_filename, 'w') as f:
    f.write(pprint.pformat(store_in_dict(
        "data_name", "training_params", "model_name", "model_params"
    )))
with open(model_txt_filename, 'w') as f:
    model.summary(print_fn=lambda x: f.write(x + '\n'))


train_checkpoint_callback = keras.callbacks.ModelCheckpoint(str(train_model_filename), monitor=monitor_function, save_best_only=False)
best_checkpoint_callback = keras.callbacks.ModelCheckpoint(str(best_model_filename), monitor=monitor_function, save_best_only=True, mode="min", verbose=1)
logger_callback = keras.callbacks.CSVLogger(str(history_csv_filename), append=True)  # more fault-tolerant than output of model.fit()
earlystopping_callback = keras.callbacks.EarlyStopping(
    monitor=monitor_function,
    mode="min",
    patience=early_stop_patience,
    verbose=0)

callback_list = [
    train_checkpoint_callback,
    best_checkpoint_callback,
    logger_callback,
    earlystopping_callback
]

model.fit(train_gen, epochs=epochs, verbose=2, validation_data=val_gen, callbacks=callback_list)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1: val_jaccard_coef_int improved from inf to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 4366s - loss: 0.3916 - accuracy: 0.8572 - jaccard_coef_int: 9.9353e-13 - val_loss: 0.4036 - val_accuracy: 0.8203 - val_jaccard_coef_int: 9.9893e-13 - 4366s/epoch - 10s/step
# Epoch 2/100
#
# Epoch 2: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.3140 - accuracy: 0.8695 - jaccard_coef_int: 8.5484e-13 - val_loss: 0.4430 - val_accuracy: 0.8247 - val_jaccard_coef_int: 9.6115e-13 - 56s/epoch - 130ms/step
# Epoch 3/100
#
# Epoch 3: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.2549 - accuracy: 0.8981 - jaccard_coef_int: 6.3154e-13 - val_loss: 0.3670 - val_accuracy: 0.8494 - val_jaccard_coef_int: 7.9688e-13 - 56s/epoch - 131ms/step
# Epoch 4/100
#
# Epoch 4: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.2268 - accuracy: 0.9112 - jaccard_coef_int: 5.4923e-13 - val_loss: 0.3436 - val_accuracy: 0.8627 - val_jaccard_coef_int: 6.6500e-13 - 56s/epoch - 131ms/step
# Epoch 5/100
#
# Epoch 5: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.2080 - accuracy: 0.9183 - jaccard_coef_int: 5.0389e-13 - val_loss: 0.3148 - val_accuracy: 0.8681 - val_jaccard_coef_int: 6.1182e-13 - 56s/epoch - 131ms/step
# Epoch 6/100
#
# Epoch 6: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1951 - accuracy: 0.9241 - jaccard_coef_int: 4.6920e-13 - val_loss: 0.3023 - val_accuracy: 0.8752 - val_jaccard_coef_int: 5.4975e-13 - 56s/epoch - 131ms/step
# Epoch 7/100
#
# Epoch 7: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.1877 - accuracy: 0.9267 - jaccard_coef_int: 4.5088e-13 - val_loss: 0.3003 - val_accuracy: 0.8788 - val_jaccard_coef_int: 5.6367e-13 - 55s/epoch - 130ms/step
# Epoch 8/100
#
# Epoch 8: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1800 - accuracy: 0.9303 - jaccard_coef_int: 4.3218e-13 - val_loss: 0.2854 - val_accuracy: 0.8834 - val_jaccard_coef_int: 4.9904e-13 - 56s/epoch - 130ms/step
# Epoch 9/100
#
# Epoch 9: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.1713 - accuracy: 0.9333 - jaccard_coef_int: 4.1352e-13 - val_loss: 0.2802 - val_accuracy: 0.8874 - val_jaccard_coef_int: 5.3564e-13 - 55s/epoch - 130ms/step
# Epoch 10/100
#
# Epoch 10: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.1663 - accuracy: 0.9354 - jaccard_coef_int: 4.0249e-13 - val_loss: 0.2756 - val_accuracy: 0.8904 - val_jaccard_coef_int: 5.1005e-13 - 55s/epoch - 129ms/step
# Epoch 11/100
#
# Epoch 11: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.1614 - accuracy: 0.9375 - jaccard_coef_int: 3.8959e-13 - val_loss: 0.2802 - val_accuracy: 0.8884 - val_jaccard_coef_int: 5.5257e-13 - 55s/epoch - 130ms/step
# Epoch 12/100
#
# Epoch 12: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1557 - accuracy: 0.9397 - jaccard_coef_int: 3.7771e-13 - val_loss: 0.2629 - val_accuracy: 0.8940 - val_jaccard_coef_int: 4.8884e-13 - 56s/epoch - 130ms/step
# Epoch 13/100
#
# Epoch 13: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 56s - loss: 0.1528 - accuracy: 0.9409 - jaccard_coef_int: 3.6977e-13 - val_loss: 0.2598 - val_accuracy: 0.8944 - val_jaccard_coef_int: 5.0988e-13 - 56s/epoch - 130ms/step
# Epoch 14/100
#
# Epoch 14: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1450 - accuracy: 0.9440 - jaccard_coef_int: 3.5314e-13 - val_loss: 0.2562 - val_accuracy: 0.8996 - val_jaccard_coef_int: 4.6877e-13 - 56s/epoch - 130ms/step
# Epoch 15/100
#
# Epoch 15: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1437 - accuracy: 0.9445 - jaccard_coef_int: 3.5090e-13 - val_loss: 0.2520 - val_accuracy: 0.9007 - val_jaccard_coef_int: 4.6377e-13 - 56s/epoch - 131ms/step
# Epoch 16/100
#
# Epoch 16: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 56s - loss: 0.1372 - accuracy: 0.9469 - jaccard_coef_int: 3.3646e-13 - val_loss: 0.2515 - val_accuracy: 0.9016 - val_jaccard_coef_int: 4.7038e-13 - 56s/epoch - 131ms/step
# Epoch 17/100
#
# Epoch 17: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1331 - accuracy: 0.9484 - jaccard_coef_int: 3.2831e-13 - val_loss: 0.2474 - val_accuracy: 0.9001 - val_jaccard_coef_int: 4.5582e-13 - 56s/epoch - 131ms/step
# Epoch 18/100
#
# Epoch 18: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1290 - accuracy: 0.9500 - jaccard_coef_int: 3.1849e-13 - val_loss: 0.2452 - val_accuracy: 0.9010 - val_jaccard_coef_int: 4.3244e-13 - 56s/epoch - 131ms/step
# Epoch 19/100
#
# Epoch 19: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 56s - loss: 0.1256 - accuracy: 0.9514 - jaccard_coef_int: 3.0996e-13 - val_loss: 0.2445 - val_accuracy: 0.9013 - val_jaccard_coef_int: 4.8006e-13 - 56s/epoch - 131ms/step
# Epoch 20/100
#
# Epoch 20: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.1240 - accuracy: 0.9521 - jaccard_coef_int: 3.0660e-13 - val_loss: 0.2372 - val_accuracy: 0.9053 - val_jaccard_coef_int: 4.3428e-13 - 55s/epoch - 130ms/step
# Epoch 21/100
#
# Epoch 21: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.1195 - accuracy: 0.9536 - jaccard_coef_int: 2.9771e-13 - val_loss: 0.2391 - val_accuracy: 0.9058 - val_jaccard_coef_int: 4.4835e-13 - 55s/epoch - 130ms/step
# Epoch 22/100
#
# Epoch 22: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.1132 - accuracy: 0.9563 - jaccard_coef_int: 2.8273e-13 - val_loss: 0.2352 - val_accuracy: 0.9068 - val_jaccard_coef_int: 4.5234e-13 - 55s/epoch - 129ms/step
# Epoch 23/100
#
# Epoch 23: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.1105 - accuracy: 0.9572 - jaccard_coef_int: 2.7573e-13 - val_loss: 0.2370 - val_accuracy: 0.9071 - val_jaccard_coef_int: 4.2784e-13 - 56s/epoch - 130ms/step
# Epoch 24/100
#
# Epoch 24: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 56s - loss: 0.1047 - accuracy: 0.9595 - jaccard_coef_int: 2.6342e-13 - val_loss: 0.2503 - val_accuracy: 0.9093 - val_jaccard_coef_int: 4.4119e-13 - 56s/epoch - 130ms/step
# Epoch 25/100
#
# Epoch 25: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.0997 - accuracy: 0.9613 - jaccard_coef_int: 2.5253e-13 - val_loss: 0.2615 - val_accuracy: 0.9057 - val_jaccard_coef_int: 4.2862e-13 - 55s/epoch - 129ms/step
# Epoch 26/100
#
# Epoch 26: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.0973 - accuracy: 0.9622 - jaccard_coef_int: 2.4784e-13 - val_loss: 0.2569 - val_accuracy: 0.9092 - val_jaccard_coef_int: 4.3360e-13 - 55s/epoch - 130ms/step
# Epoch 27/100
#
# Epoch 27: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 56s - loss: 0.0954 - accuracy: 0.9630 - jaccard_coef_int: 2.4229e-13 - val_loss: 0.2545 - val_accuracy: 0.9073 - val_jaccard_coef_int: 4.3364e-13 - 56s/epoch - 130ms/step
# Epoch 28/100
#
# Epoch 28: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.0891 - accuracy: 0.9654 - jaccard_coef_int: 2.2805e-13 - val_loss: 0.2733 - val_accuracy: 0.9089 - val_jaccard_coef_int: 4.2548e-13 - 56s/epoch - 130ms/step
# Epoch 29/100
#
# Epoch 29: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 56s - loss: 0.0833 - accuracy: 0.9675 - jaccard_coef_int: 2.1562e-13 - val_loss: 0.2717 - val_accuracy: 0.9075 - val_jaccard_coef_int: 4.2552e-13 - 56s/epoch - 131ms/step
# Epoch 30/100
#
# Epoch 30: val_jaccard_coef_int improved from 0.00000 to 0.00000, saving model to Staten Island Progress/model_best.h5
# 427/427 - 56s - loss: 0.0788 - accuracy: 0.9693 - jaccard_coef_int: 2.0449e-13 - val_loss: 0.2764 - val_accuracy: 0.9080 - val_jaccard_coef_int: 4.2146e-13 - 56s/epoch - 130ms/step
# Epoch 31/100
#
# Epoch 31: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 56s - loss: 0.0784 - accuracy: 0.9693 - jaccard_coef_int: 2.0388e-13 - val_loss: 0.2934 - val_accuracy: 0.9051 - val_jaccard_coef_int: 4.3045e-13 - 56s/epoch - 131ms/step
# Epoch 32/100
#
# Epoch 32: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.0745 - accuracy: 0.9707 - jaccard_coef_int: 1.9574e-13 - val_loss: 0.2963 - val_accuracy: 0.9079 - val_jaccard_coef_int: 4.3421e-13 - 55s/epoch - 129ms/step
# Epoch 33/100
#
# Epoch 33: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.0698 - accuracy: 0.9725 - jaccard_coef_int: 1.8453e-13 - val_loss: 0.3274 - val_accuracy: 0.9081 - val_jaccard_coef_int: 4.3794e-13 - 55s/epoch - 130ms/step
# Epoch 34/100
#
# Epoch 34: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.0658 - accuracy: 0.9740 - jaccard_coef_int: 1.7551e-13 - val_loss: 0.3342 - val_accuracy: 0.9034 - val_jaccard_coef_int: 4.3542e-13 - 55s/epoch - 130ms/step
# Epoch 35/100
#
# Epoch 35: val_jaccard_coef_int did not improve from 0.00000
# 427/427 - 55s - loss: 0.0655 - accuracy: 0.9740 - jaccard_coef_int: 1.7540e-13 - val_loss: 0.3377 - val_accuracy: 0.9071 - val_jaccard_coef_int: 4.5307e-13 - 55s/epoch - 130ms/step
